# %%
import os
import sys
import numpy as np
import pandas as pd
import datetime
import time
import itertools
import pickle
import json

from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

path_main_folder = '/home/antorosi/Documents/Prediction'
sys.path.append(path_main_folder)

from conso.load_shape_data import load_data_conso, get_uniformed_data_conso, change_granularity, get_x_y_prediction_conso, get_train_test_sets, normalized_dataset, select_variables, add_atypical_events_to_dict_data_conso
from models.feedforward_NN import FeedForward
from aed.atypical_event import AtypicalEventsList, AtypicalEvent, dataframe_daily_to_ael
from aed.detection import get_next_hd_events, sort_atypical_events, get_residuals, get_atypical_score, get_atypical_ds, prediction_conso_plot, aed_conso_plot
from aed.multi_period import get_prediction_results, get_aed_results, get_complete_df
# Out:
# /local/home/antorosi/PycharmProjects/KERAS-TS-VENV/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Load and shape data

# %%
# Load
path_data = os.path.join(path_main_folder, 'data')
dict_data_conso = load_data_conso(path_data)

# %% [markdown]
# ### Folder to store results

# %%
# folder to store results
path_out = os.path.join(path_main_folder, 'out', 'iterate_FFNN_0')
if not os.path.exists(path_out):
    os.mkdir(path_out)

# %%
path_data = os.path.join("/local/home/antorosi/Documents/Prediction/data")
with open(os.path.join(path_data, 'ae_reference_list_wwe_2013-2017' + '.pickle'), 'rb') as f:
    ael_reference= pickle.load(f)

# %% [markdown]
# ### Iterative fitting parameters

# %%
# iterative parameters
nb_iter = 5
nb_ae = 50

# input parameters
selected_variables = ['calendar', 'conso','meteo', 'atypical_events']
gen_name = 'cmcaae'

# model parameters
nb_hidden_units = 171
nb_hidden_layers = 2
dropout = 0.1
training_epochs=400
batch_size=100

# atypical event list initialisation
ael = AtypicalEventsList()

# %%
# Test periods for each K step of the cross-validation
cv_periods = {}
cv_periods['period_1'] = (datetime.datetime(year=2013, month=1, day=1), datetime.datetime(year=2013, month=12, day=31))
cv_periods['period_2'] = (datetime.datetime(year=2014, month=1, day=1), datetime.datetime(year=2014, month=12, day=31))
cv_periods['period_3'] = (datetime.datetime(year=2015, month=1, day=1), datetime.datetime(year=2015, month=12, day=31))
cv_periods['period_4'] = (datetime.datetime(year=2016, month=1, day=1), datetime.datetime(year=2016, month=12, day=31))
cv_periods['period_5'] = (datetime.datetime(year=2017, month=1, day=1), datetime.datetime(year=2017, month=12, day=31))

# %% [markdown]
# ### Main loop

# %%
for iteration in range(nb_iter):
    ### Create new folder to store iteration results
    path_out_iter = os.path.join(path_out, 'iter_'+str(iteration))
    if not os.path.exists(path_out_iter):
        os.mkdir(path_out_iter)
    
    ### UPDATE DATA WITH NEW ATYPICAL EVENTS ###
    dict_data_conso = add_atypical_events_to_dict_data_conso(dict_data_conso, ael)

    # Uniformization
    data_conso_df, dict_colnames_conso = get_uniformed_data_conso(dict_data_conso)

    # Granularity from 15 min to 1H
    data_conso_df = change_granularity(data_conso_df, granularity="1H")

    # Get x and y from prediction
    x_conso, y_conso, dict_colnames_conso = get_x_y_prediction_conso(data_conso_df, dict_colnames_conso, horizon_length=24)

    # Getting each datasets
    dict_datasets = {}
    for key, date_period in cv_periods.items():
        x_conso_selected_var = select_variables(x_conso, dict_colnames_conso, selected_variables)
        dataset, dict_ds = get_train_test_sets(x_conso_selected_var, y_conso, date_period[0], date_period[1])
        dataset = normalized_dataset(dataset, dict_colnames_conso)

        dict_datasets[key] = {'dataset': dataset, 'dict_ds': dict_ds}
    
    # Deleting useless info
    del x_conso, y_conso
    
    ### Getting FFNN input dim ###
    input_dim = dict_datasets['period_1']['dataset']['train']['x'].shape[1]

    ### Prepare results wrap up ###
    results_df = pd.DataFrame(columns=['name', 'layer_dims','dropout_rates','batchsize',
                                               'best_iter', 'train_mse',
                                               'train_mae', 'train_mape',
                                               'test_mse', 'test_mae',
                                               'test_mape'])
    path_results = path_out_iter
    
    ### TRAINNING ###
    
    idx = 0

    for name_period, el in dict_datasets.items():
        dataset = el['dataset']

        print('========================= Iteration {} Model {} ========================='.format(iteration+1,idx+1))

        # Prepare model characteristics
        name_model = '{}_LR_{}_norm'.format(name_period, gen_name)

        path_model = os.path.join(path_out_iter, name_model)
        if not os.path.exists(path_model):
            os.mkdir(path_model)

        # Compile model
        model = linear_model.LinearRegression(n_jobs=-1)

        # Train model
        model.fit(X=dataset['train']['x'], y=np.ravel(dataset['train']['y']))
        
        # Save model
        with open(os.path.join(path_model,'model.pickle'),'wb') as f:
            pickle.dump(model,f)
        
        # Get result and put it in results
        y_train = np.ravel(dataset['train']['y'])
        y_hat_train = model.predict(dataset['train']['x'])
        y_test= np.ravel(dataset['test']['y'])
        y_hat_test = model.predict(dataset['test']['x'])

        result = {}
        result['name'] = name_model

        result['train_mse'] = mean_squared_error(y_train, y_hat_train)
        result['train_mae'] = mean_absolute_error(y_train, y_hat_train)
        result['train_mape'] = mean_absolute_percentage_error(y_train, y_hat_train)
        result['test_mse'] = mean_squared_error(y_test, y_hat_test)
        result['test_mae'] = mean_absolute_error(y_test, y_hat_test)
        result['test_mape'] = mean_absolute_percentage_error(y_test, y_hat_test)

        # Append result to results_df
    
        results_df= results_df.append(result, ignore_index=True)
        results_df.to_csv(os.path.join(path_results, 'cv_results.csv'), sep=';')
        

    ### Atypical Event Detection ###
    path_models_folder = path_out_iter
    mode = 2
    type_model = 'sklearn'
    
    # get prediction
    prediction_results = get_prediction_results(path_models_folder, dict_datasets, mode, type_model)
    
    # get atypical events info
    threshold = 0.95
    aed_results, ael_full_model = get_aed_results(prediction_results, threshold)
    
    # get complete dataframe
    atypical_full_df, prediction_full_df = get_complete_df(prediction_results, aed_results)
    
    # sort events
    atypical_new_df = sort_atypical_events(atypical_full_df, ael_reference)
    
    # get ael
    selected_ae_iter = atypical_new_df[:nb_ae]
    ael_iter = dataframe_daily_to_ael(selected_ae_iter)
    
    # merge ael
    ael = ael.get_union(ael_iter)
    
    ### Save results ###

    # plot 
    # Not working with the current method
    #path_plot = path_results
    #name_plot = 'full_period_mode{}_t{}_iter{}.html'.format(mode, threshold, iteration)
    #aed_conso_plot(data_conso_df, atypical_full_df, prediction_full_df, dict_colnames_conso, path_plot, name_plot)
    
    # data
    with open(os.path.join(path_results, 'atypical_full_df.json'),'wb') as f:
        pickle.dump(atypical_full_df,f)
    with open(os.path.join(path_results, 'prediction_full_df.json'),'wb') as f:
        pickle.dump(atypical_full_df,f)
    with open(os.path.join(path_results, 'selected_ae_iter.json'),'wb') as f:
        pickle.dump(atypical_full_df,f)
    
    ael.get_events_list().to_csv(os.path.join(path_results, 'ael.csv'), sep=';')
# Out:
# ========================= Model 1 =========================
# model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_input (InputLayer)     (None, 156)               0
# _________________________________________________________________
# dense_hidden_0 (Dense)       (None, 171)               26847
# _________________________________________________________________
# dropout_hidden_0 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_hidden_1 (Dense)       (None, 171)               29412
# _________________________________________________________________
# dropout_hidden_1 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_output (Dense)         (None, 1)                 172
# =================================================================
# Total params: 56,431
# Trainable params: 56,431
# Non-trainable params: 0
# _________________________________________________________________
#
#
# --- START TRAINING ---
#
# Train on 35108 samples, validate on 8759 samples
# Epoch 1/5
# 35108/35108 [==============================] - 0s 14us/step - loss: 3055274062.1388 - mean_absolute_percentage_error: 99.9897 - mean_absolute_error: 54024.8787 - val_loss: 3325517604.0078 - val_mean_absolute_percentage_error: 99.9717 - val_mean_absolute_error: 56171.2990
# Epoch 2/5
# 35108/35108 [==============================] - 0s 11us/step - loss: 3052616903.5032 - mean_absolute_percentage_error: 99.9449 - mean_absolute_error: 54001.0831 - val_loss: 3320221299.6516 - val_mean_absolute_percentage_error: 99.8925 - val_mean_absolute_error: 56126.7145
# Epoch 3/5
# 35108/35108 [==============================] - 0s 10us/step - loss: 3045660141.5080 - mean_absolute_percentage_error: 99.8278 - mean_absolute_error: 53938.7067 - val_loss: 3307768402.4788 - val_mean_absolute_percentage_error: 99.7061 - val_mean_absolute_error: 56021.7866
# Epoch 4/5
# 35108/35108 [==============================] - 0s 11us/step - loss: 3030917140.2420 - mean_absolute_percentage_error: 99.5794 - mean_absolute_error: 53806.3285 - val_loss: 3283542147.1711 - val_mean_absolute_percentage_error: 99.3417 - val_mean_absolute_error: 55816.8098
# Epoch 5/5
# 35108/35108 [==============================] - 0s 11us/step - loss: 3003940915.3342 - mean_absolute_percentage_error: 99.1210 - mean_absolute_error: 53562.4840 - val_loss: 3241943800.3425 - val_mean_absolute_percentage_error: 98.7116 - val_mean_absolute_error: 55462.4079
#                                       name  layer_dims dropout_rates  \
# 0  period_1_FFNN_l171*2_d0.1*2_cmcaae_norm  [171, 171]    [0.1, 0.1]
#
#   batchsize best_iter     train_mse     train_mae  train_mape      test_mse  \
# 0      3000         5  2.982904e+09  53371.630477   98.762611  3.241944e+09
#
#        test_mae  test_mape
# 0  55462.403771  98.711546
# ========================= Model 2 =========================
# model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_input (InputLayer)     (None, 156)               0
# _________________________________________________________________
# dense_hidden_0 (Dense)       (None, 171)               26847
# _________________________________________________________________
# dropout_hidden_0 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_hidden_1 (Dense)       (None, 171)               29412
# _________________________________________________________________
# dropout_hidden_1 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_output (Dense)         (None, 1)                 172
# =================================================================
# Total params: 56,431
# Trainable params: 56,431
# Non-trainable params: 0
# _________________________________________________________________
#
#
# --- START TRAINING ---
#
# Train on 35108 samples, validate on 8759 samples
# Epoch 1/5
# 35108/35108 [==============================] - 1s 14us/step - loss: 3123881731.1209 - mean_absolute_percentage_error: 99.9903 - mean_absolute_error: 54568.7147 - val_loss: 3051007692.7357 - val_mean_absolute_percentage_error: 99.9744 - val_mean_absolute_error: 53995.0003
# Epoch 2/5
# 35108/35108 [==============================] - 0s 10us/step - loss: 3121166234.4692 - mean_absolute_percentage_error: 99.9458 - mean_absolute_error: 54544.7312 - val_loss: 3046543245.7806 - val_mean_absolute_percentage_error: 99.8992 - val_mean_absolute_error: 53955.0060
# Epoch 3/5
# 35108/35108 [==============================] - 0s 10us/step - loss: 3113791006.2755 - mean_absolute_percentage_error: 99.8244 - mean_absolute_error: 54479.4823 - val_loss: 3035660786.7309 - val_mean_absolute_percentage_error: 99.7149 - val_mean_absolute_error: 53857.1091
# Epoch 4/5
# 35108/35108 [==============================] - 0s 11us/step - loss: 3097692055.9025 - mean_absolute_percentage_error: 99.5585 - mean_absolute_error: 54336.5361 - val_loss: 3014173009.1928 - val_mean_absolute_percentage_error: 99.3483 - val_mean_absolute_error: 53662.7370
# Epoch 5/5
# 35108/35108 [==============================] - 0s 11us/step - loss: 3068205536.7328 - mean_absolute_percentage_error: 99.0673 - mean_absolute_error: 54072.9473 - val_loss: 2977202517.8984 - val_mean_absolute_percentage_error: 98.7123 - val_mean_absolute_error: 53325.7236
#                                       name  layer_dims dropout_rates  \
# 0  period_3_FFNN_l171*2_d0.1*2_cmcaae_norm  [171, 171]    [0.1, 0.1]
#
#   batchsize best_iter     train_mse    train_mae  train_mape      test_mse  \
# 0      3000         5  3.044938e+09  53864.00935   98.678139  2.977203e+09
#
#        test_mae  test_mape
# 0  53325.718455  98.712268
# ========================= Model 3 =========================
# model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_input (InputLayer)     (None, 156)               0
# _________________________________________________________________
# dense_hidden_0 (Dense)       (None, 171)               26847
# _________________________________________________________________
# dropout_hidden_0 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_hidden_1 (Dense)       (None, 171)               29412
# _________________________________________________________________
# dropout_hidden_1 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_output (Dense)         (None, 1)                 172
# =================================================================
# Total params: 56,431
# Trainable params: 56,431
# Non-trainable params: 0
# _________________________________________________________________
#
#
# --- START TRAINING ---
#
# Train on 35132 samples, validate on 8735 samples
# Epoch 1/5
# 35132/35132 [==============================] - 0s 14us/step - loss: 3100693561.7115 - mean_absolute_percentage_error: 99.9909 - mean_absolute_error: 54406.7354 - val_loss: 3144318553.0944 - val_mean_absolute_percentage_error: 99.9734 - val_mean_absolute_error: 54646.3747
# Epoch 2/5
# 35132/35132 [==============================] - 0s 11us/step - loss: 3098167622.7986 - mean_absolute_percentage_error: 99.9476 - mean_absolute_error: 54383.9110 - val_loss: 3139472644.5426 - val_mean_absolute_percentage_error: 99.8921 - val_mean_absolute_error: 54603.1681
# Epoch 3/5
# 35132/35132 [==============================] - 0s 11us/step - loss: 3091098032.9527 - mean_absolute_percentage_error: 99.8273 - mean_absolute_error: 54320.2320 - val_loss: 3127537357.0052 - val_mean_absolute_percentage_error: 99.6930 - val_mean_absolute_error: 54496.9662
# Epoch 4/5
# 35132/35132 [==============================] - 0s 10us/step - loss: 3075587378.3372 - mean_absolute_percentage_error: 99.5642 - mean_absolute_error: 54180.5121 - val_loss: 3103718060.0343 - val_mean_absolute_percentage_error: 99.2949 - val_mean_absolute_error: 54284.3844
# Epoch 5/5
# 35132/35132 [==============================] - 0s 10us/step - loss: 3046859611.4057 - mean_absolute_percentage_error: 99.0739 - mean_absolute_error: 53920.2366 - val_loss: 3062522938.3217 - val_mean_absolute_percentage_error: 98.6020 - val_mean_absolute_error: 53914.1945
#                                       name  layer_dims dropout_rates  \
# 0  period_5_FFNN_l171*2_d0.1*2_cmcaae_norm  [171, 171]    [0.1, 0.1]
#
#   batchsize best_iter     train_mse     train_mae  train_mape      test_mse  \
# 0      3000         5  3.024236e+09  53714.616035   98.687081  3.062523e+09
#
#        test_mae  test_mape
# 0  53914.199331  98.601962
# ========================= Model 4 =========================
# model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_input (InputLayer)     (None, 156)               0
# _________________________________________________________________
# dense_hidden_0 (Dense)       (None, 171)               26847
# _________________________________________________________________
# dropout_hidden_0 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_hidden_1 (Dense)       (None, 171)               29412
# _________________________________________________________________
# dropout_hidden_1 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_output (Dense)         (None, 1)                 172
# =================================================================
# Total params: 56,431
# Trainable params: 56,431
# Non-trainable params: 0
# _________________________________________________________________
#
#
# --- START TRAINING ---
#
# Train on 35108 samples, validate on 8759 samples
# Epoch 1/5
# 35108/35108 [==============================] - 0s 11us/step - loss: 3160850661.1662 - mean_absolute_percentage_error: 99.9908 - mean_absolute_error: 54875.5454 - val_loss: 2903081478.4007 - val_mean_absolute_percentage_error: 99.9768 - val_mean_absolute_error: 52767.4531
# Epoch 2/5
# 35108/35108 [==============================] - 0s 10us/step - loss: 3158132323.3433 - mean_absolute_percentage_error: 99.9471 - mean_absolute_error: 54851.8029 - val_loss: 2899210387.3337 - val_mean_absolute_percentage_error: 99.9072 - val_mean_absolute_error: 52731.4866
# Epoch 3/5
# 35108/35108 [==============================] - 0s 12us/step - loss: 3150883860.0962 - mean_absolute_percentage_error: 99.8295 - mean_absolute_error: 54788.1235 - val_loss: 2890050548.5722 - val_mean_absolute_percentage_error: 99.7415 - val_mean_absolute_error: 52646.0705
# Epoch 4/5
# 35108/35108 [==============================] - 0s 10us/step - loss: 3135483282.8857 - mean_absolute_percentage_error: 99.5777 - mean_absolute_error: 54652.1671 - val_loss: 2872190762.2916 - val_mean_absolute_percentage_error: 99.4163 - val_mean_absolute_error: 52478.6688
# Epoch 5/5
# 35108/35108 [==============================] - 0s 10us/step - loss: 3107494850.8657 - mean_absolute_percentage_error: 99.1161 - mean_absolute_error: 54403.3726 - val_loss: 2841404488.5708 - val_mean_absolute_percentage_error: 98.8510 - val_mean_absolute_error: 52188.0750
#                                       name  layer_dims dropout_rates  \
# 0  period_2_FFNN_l171*2_d0.1*2_cmcaae_norm  [171, 171]    [0.1, 0.1]
#
#   batchsize best_iter     train_mse     train_mae  train_mape      test_mse  \
# 0      3000         5  3.085368e+09  54205.762596   98.749425  2.841404e+09
#
#        test_mae  test_mape
# 0  52188.074389  98.851058
# ========================= Model 5 =========================
# model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_input (InputLayer)     (None, 156)               0
# _________________________________________________________________
# dense_hidden_0 (Dense)       (None, 171)               26847
# _________________________________________________________________
# dropout_hidden_0 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_hidden_1 (Dense)       (None, 171)               29412
# _________________________________________________________________
# dropout_hidden_1 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_output (Dense)         (None, 1)                 172
# =================================================================
# Total params: 56,431
# Trainable params: 56,431
# Non-trainable params: 0
# _________________________________________________________________
#
#
# --- START TRAINING ---
#
# Train on 35084 samples, validate on 8783 samples
# Epoch 1/5
# 35084/35084 [==============================] - 0s 12us/step - loss: 3106978422.6455 - mean_absolute_percentage_error: 99.9888 - mean_absolute_error: 54406.5459 - val_loss: 3117908305.7579 - val_mean_absolute_percentage_error: 99.9706 - val_mean_absolute_error: 54638.1039
# Epoch 2/5
# 35084/35084 [==============================] - 0s 10us/step - loss: 3103955073.1237 - mean_absolute_percentage_error: 99.9406 - mean_absolute_error: 54380.2390 - val_loss: 3112700722.1332 - val_mean_absolute_percentage_error: 99.8854 - val_mean_absolute_error: 54592.0300
# Epoch 3/5
# 35084/35084 [==============================] - 0s 13us/step - loss: 3095790479.4546 - mean_absolute_percentage_error: 99.8088 - mean_absolute_error: 54308.6873 - val_loss: 3100161550.8359 - val_mean_absolute_percentage_error: 99.6772 - val_mean_absolute_error: 54480.1631
# Epoch 4/5
# 35084/35084 [==============================] - 1s 18us/step - loss: 3078274656.9303 - mean_absolute_percentage_error: 99.5224 - mean_absolute_error: 54153.9847 - val_loss: 3075816970.2307 - val_mean_absolute_percentage_error: 99.2690 - val_mean_absolute_error: 54261.4764
# Epoch 5/5
# 35084/35084 [==============================] - 1s 15us/step - loss: 3046538611.7560 - mean_absolute_percentage_error: 98.9991 - mean_absolute_error: 53871.7291 - val_loss: 3034235407.9727 - val_mean_absolute_percentage_error: 98.5647 - val_mean_absolute_error: 53884.6826
#                                       name  layer_dims dropout_rates  \
# 0  period_4_FFNN_l171*2_d0.1*2_cmcaae_norm  [171, 171]    [0.1, 0.1]
#
#   batchsize best_iter     train_mse     train_mae  train_mape      test_mse  \
# 0      3000         5  3.021627e+09  53648.565619   98.584635  3.034235e+09
#
#        test_mae  test_mape
# 0  53884.686499  98.564761
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]
# [ (2,1) x1,y2 ]
# [ (3,1) x1,y3 ]
# [ (4,1) x1,y4 ]
# /local/home/antorosi/PycharmProjects/KERAS-TS-VENV/lib/python3.5/site-packages/plotly/offline/offline.py:459: UserWarning:
#
# Your filename `/home/antorosi/Documents/Prediction/out/iterate_FFNN_0/iter-0/full_period_mode2_t0.95_iter0` didn't end with .html. Adding .html to the end of your file.
# ========================= Model 1 =========================
# model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_input (InputLayer)     (None, 156)               0
# _________________________________________________________________
# dense_hidden_0 (Dense)       (None, 171)               26847
# _________________________________________________________________
# dropout_hidden_0 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_hidden_1 (Dense)       (None, 171)               29412
# _________________________________________________________________
# dropout_hidden_1 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_output (Dense)         (None, 1)                 172
# =================================================================
# Total params: 56,431
# Trainable params: 56,431
# Non-trainable params: 0
# _________________________________________________________________
#
#
# --- START TRAINING ---
#
# Train on 35108 samples, validate on 8759 samples
# Epoch 1/5
# 35108/35108 [==============================] - 0s 13us/step - loss: 3055289388.6549 - mean_absolute_percentage_error: 99.9904 - mean_absolute_error: 54025.1428 - val_loss: 3325510563.5255 - val_mean_absolute_percentage_error: 99.9727 - val_mean_absolute_error: 56171.5282
# Epoch 2/5
# 35108/35108 [==============================] - 0s 10us/step - loss: 3052674612.3842 - mean_absolute_percentage_error: 99.9476 - mean_absolute_error: 54002.0698 - val_loss: 3320172832.2375 - val_mean_absolute_percentage_error: 99.8956 - val_mean_absolute_error: 56127.3669
# Epoch 3/5
# 35108/35108 [==============================] - 0s 10us/step - loss: 3045698772.2493 - mean_absolute_percentage_error: 99.8338 - mean_absolute_error: 53940.4988 - val_loss: 3307364875.1063 - val_mean_absolute_percentage_error: 99.7096 - val_mean_absolute_error: 56021.0265
# Epoch 4/5
# 35108/35108 [==============================] - 0s 10us/step - loss: 3030599629.6575 - mean_absolute_percentage_error: 99.5860 - mean_absolute_error: 53806.7189 - val_loss: 3281967665.1307 - val_mean_absolute_percentage_error: 99.3386 - val_mean_absolute_error: 55809.1406
# Epoch 5/5
# 35108/35108 [==============================] - 0s 10us/step - loss: 3002890545.6425 - mean_absolute_percentage_error: 99.1280 - mean_absolute_error: 53559.7443 - val_loss: 3238443637.5221 - val_mean_absolute_percentage_error: 98.6977 - val_mean_absolute_error: 55443.3493
#                                       name  layer_dims dropout_rates  \
# 0  period_1_FFNN_l171*2_d0.1*2_cmcaae_norm  [171, 171]    [0.1, 0.1]
#
#   batchsize best_iter     train_mse     train_mae  train_mape      test_mse  \
# 0      3000         5  2.981118e+09  53364.507183   98.765586  3.238444e+09
#
#        test_mae  test_mape
# 0  55443.348522  98.697684
# ========================= Model 2 =========================
# model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_input (InputLayer)     (None, 156)               0
# _________________________________________________________________
# dense_hidden_0 (Dense)       (None, 171)               26847
# _________________________________________________________________
# dropout_hidden_0 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_hidden_1 (Dense)       (None, 171)               29412
# _________________________________________________________________
# dropout_hidden_1 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_output (Dense)         (None, 1)                 172
# =================================================================
# Total params: 56,431
# Trainable params: 56,431
# Non-trainable params: 0
# _________________________________________________________________
#
#
# --- START TRAINING ---
#
# Train on 35108 samples, validate on 8759 samples
# Epoch 1/5
# 35108/35108 [==============================] - 1s 26us/step - loss: 3124027778.1730 - mean_absolute_percentage_error: 99.9929 - mean_absolute_error: 54570.0732 - val_loss: 3051305532.3831 - val_mean_absolute_percentage_error: 99.9795 - val_mean_absolute_error: 53997.6945
# Epoch 2/5
# 35108/35108 [==============================] - 1s 18us/step - loss: 3121787746.0599 - mean_absolute_percentage_error: 99.9559 - mean_absolute_error: 54550.2118 - val_loss: 3047620044.8234 - val_mean_absolute_percentage_error: 99.9172 - val_mean_absolute_error: 53964.5921
# Epoch 3/5
# 35108/35108 [==============================] - 0s 12us/step - loss: 3115673950.4140 - mean_absolute_percentage_error: 99.8551 - mean_absolute_error: 54496.0596 - val_loss: 3038635972.6983 - val_mean_absolute_percentage_error: 99.7643 - val_mean_absolute_error: 53883.6100
# Epoch 4/5
# 35108/35108 [==============================] - 0s 11us/step - loss: 3102303014.8215 - mean_absolute_percentage_error: 99.6331 - mean_absolute_error: 54377.0675 - val_loss: 3020766476.0123 - val_mean_absolute_percentage_error: 99.4576 - val_mean_absolute_error: 53721.5535
# Epoch 5/5
# 35108/35108 [==============================] - 0s 10us/step - loss: 3077692104.5824 - mean_absolute_percentage_error: 99.2209 - mean_absolute_error: 54156.6292 - val_loss: 2989757603.2332 - val_mean_absolute_percentage_error: 98.9207 - val_mean_absolute_error: 53438.2446
#                                       name  layer_dims dropout_rates  \
# 0  period_3_FFNN_l171*2_d0.1*2_cmcaae_norm  [171, 171]    [0.1, 0.1]
#
#   batchsize best_iter     train_mse     train_mae  train_mape      test_mse  \
# 0      3000         5  3.058293e+09  53981.683448   98.892982  2.989758e+09
#
#        test_mae  test_mape
# 0  53438.248026  98.920751
# ========================= Model 3 =========================
# model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_input (InputLayer)     (None, 156)               0
# _________________________________________________________________
# dense_hidden_0 (Dense)       (None, 171)               26847
# _________________________________________________________________
# dropout_hidden_0 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_hidden_1 (Dense)       (None, 171)               29412
# _________________________________________________________________
# dropout_hidden_1 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_output (Dense)         (None, 1)                 172
# =================================================================
# Total params: 56,431
# Trainable params: 56,431
# Non-trainable params: 0
# _________________________________________________________________
#
#
# --- START TRAINING ---
#
# Train on 35132 samples, validate on 8735 samples
# Epoch 1/5
# 35132/35132 [==============================] - 0s 14us/step - loss: 3100774360.1558 - mean_absolute_percentage_error: 99.9927 - mean_absolute_error: 54407.5899 - val_loss: 3144528054.5850 - val_mean_absolute_percentage_error: 99.9776 - val_mean_absolute_error: 54648.4438
# Epoch 2/5
# 35132/35132 [==============================] - 0s 11us/step - loss: 3098649677.8814 - mean_absolute_percentage_error: 99.9567 - mean_absolute_error: 54388.4840 - val_loss: 3140603147.2833 - val_mean_absolute_percentage_error: 99.9123 - val_mean_absolute_error: 54613.5689
# Epoch 3/5
# 35132/35132 [==============================] - 0s 10us/step - loss: 3092915600.5119 - mean_absolute_percentage_error: 99.8598 - mean_absolute_error: 54337.0023 - val_loss: 3130895653.8065 - val_mean_absolute_percentage_error: 99.7519 - val_mean_absolute_error: 54527.6401
# Epoch 4/5
# 35132/35132 [==============================] - 0s 10us/step - loss: 3080252570.9466 - mean_absolute_percentage_error: 99.6472 - mean_absolute_error: 54223.5830 - val_loss: 3111429718.6033 - val_mean_absolute_percentage_error: 99.4309 - val_mean_absolute_error: 54355.2168
# Epoch 5/5
# 35132/35132 [==============================] - 0s 10us/step - loss: 3056596913.9146 - mean_absolute_percentage_error: 99.2497 - mean_absolute_error: 54011.1941 - val_loss: 3077350154.8437 - val_mean_absolute_percentage_error: 98.8672 - val_mean_absolute_error: 54052.0404
#                                       name  layer_dims dropout_rates  \
# 0  period_5_FFNN_l171*2_d0.1*2_cmcaae_norm  [171, 171]    [0.1, 0.1]
#
#   batchsize best_iter     train_mse     train_mae  train_mape      test_mse  \
# 0      3000         5  3.037841e+09  53842.184163   98.933599  3.077350e+09
#
#        test_mae  test_mape
# 0  54052.031142  98.867145
# ========================= Model 4 =========================
# model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_input (InputLayer)     (None, 156)               0
# _________________________________________________________________
# dense_hidden_0 (Dense)       (None, 171)               26847
# _________________________________________________________________
# dropout_hidden_0 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_hidden_1 (Dense)       (None, 171)               29412
# _________________________________________________________________
# dropout_hidden_1 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_output (Dense)         (None, 1)                 172
# =================================================================
# Total params: 56,431
# Trainable params: 56,431
# Non-trainable params: 0
# _________________________________________________________________
#
#
# --- START TRAINING ---
#
# Train on 35108 samples, validate on 8759 samples
# Epoch 1/5
# 35108/35108 [==============================] - 0s 12us/step - loss: 3160988647.0329 - mean_absolute_percentage_error: 99.9926 - mean_absolute_error: 54876.6325 - val_loss: 2903351596.2790 - val_mean_absolute_percentage_error: 99.9808 - val_mean_absolute_error: 52769.7225
# Epoch 2/5
# 35108/35108 [==============================] - 0s 11us/step - loss: 3158917923.9923 - mean_absolute_percentage_error: 99.9580 - mean_absolute_error: 54858.1910 - val_loss: 2900382021.3559 - val_mean_absolute_percentage_error: 99.9265 - val_mean_absolute_error: 52741.8776
# Epoch 3/5
# 35108/35108 [==============================] - 0s 10us/step - loss: 3153284458.2851 - mean_absolute_percentage_error: 99.8651 - mean_absolute_error: 54808.3005 - val_loss: 2893096525.8317 - val_mean_absolute_percentage_error: 99.7934 - val_mean_absolute_error: 52673.6224
# Epoch 4/5
# 35108/35108 [==============================] - 0s 10us/step - loss: 3140945860.2074 - mean_absolute_percentage_error: 99.6617 - mean_absolute_error: 54698.9538 - val_loss: 2878524522.3281 - val_mean_absolute_percentage_error: 99.5270 - val_mean_absolute_error: 52536.8150
# Epoch 5/5
# 35108/35108 [==============================] - 0s 10us/step - loss: 3117880525.3658 - mean_absolute_percentage_error: 99.2814 - mean_absolute_error: 54494.1394 - val_loss: 2853107794.8880 - val_mean_absolute_percentage_error: 99.0602 - val_mean_absolute_error: 52297.1224
#                                       name  layer_dims dropout_rates  \
# 0  period_2_FFNN_l171*2_d0.1*2_cmcaae_norm  [171, 171]    [0.1, 0.1]
#
#   batchsize best_iter     train_mse     train_mae  train_mape      test_mse  \
# 0      3000         5  3.099669e+09  54331.395319   98.978561  2.853108e+09
#
#        test_mae  test_mape
# 0  52297.125576  99.060204
# ========================= Model 5 =========================
# model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_input (InputLayer)     (None, 156)               0
# _________________________________________________________________
# dense_hidden_0 (Dense)       (None, 171)               26847
# _________________________________________________________________
# dropout_hidden_0 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_hidden_1 (Dense)       (None, 171)               29412
# _________________________________________________________________
# dropout_hidden_1 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_output (Dense)         (None, 1)                 172
# =================================================================
# Total params: 56,431
# Trainable params: 56,431
# Non-trainable params: 0
# _________________________________________________________________
#
#
# --- START TRAINING ---
#
# Train on 35084 samples, validate on 8783 samples
# Epoch 1/5
# 35084/35084 [==============================] - 0s 13us/step - loss: 3107153943.1162 - mean_absolute_percentage_error: 99.9916 - mean_absolute_error: 54408.0516 - val_loss: 3118276278.6365 - val_mean_absolute_percentage_error: 99.9764 - val_mean_absolute_error: 54641.3002
# Epoch 2/5
# 35084/35084 [==============================] - 0s 11us/step - loss: 3104700344.6084 - mean_absolute_percentage_error: 99.9524 - mean_absolute_error: 54386.7074 - val_loss: 3114094868.4031 - val_mean_absolute_percentage_error: 99.9081 - val_mean_absolute_error: 54604.3264
# Epoch 3/5
# 35084/35084 [==============================] - 0s 10us/step - loss: 3098213999.9909 - mean_absolute_percentage_error: 99.8482 - mean_absolute_error: 54330.0251 - val_loss: 3104146006.5672 - val_mean_absolute_percentage_error: 99.7445 - val_mean_absolute_error: 54516.0254
# Epoch 4/5
# 35084/35084 [==============================] - 0s 10us/step - loss: 3084241168.3740 - mean_absolute_percentage_error: 99.6228 - mean_absolute_error: 54207.4906 - val_loss: 3084492308.5196 - val_mean_absolute_percentage_error: 99.4192 - val_mean_absolute_error: 54340.7687
# Epoch 5/5
# 35084/35084 [==============================] - 0s 10us/step - loss: 3058473359.1043 - mean_absolute_percentage_error: 99.2030 - mean_absolute_error: 53979.9508 - val_loss: 3050352729.9483 - val_mean_absolute_percentage_error: 98.8498 - val_mean_absolute_error: 54034.2202
#                                       name  layer_dims dropout_rates  \
# 0  period_4_FFNN_l171*2_d0.1*2_cmcaae_norm  [171, 171]    [0.1, 0.1]
#
#   batchsize best_iter     train_mse    train_mae  train_mape      test_mse  \
# 0      3000         5  3.038015e+09  53798.73737   98.869076  3.050353e+09
#
#        test_mae  test_mape
# 0  54034.220875  98.849851
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]
# [ (2,1) x1,y2 ]
# [ (3,1) x1,y3 ]
# [ (4,1) x1,y4 ]
# /local/home/antorosi/PycharmProjects/KERAS-TS-VENV/lib/python3.5/site-packages/plotly/offline/offline.py:459: UserWarning:
#
# Your filename `/home/antorosi/Documents/Prediction/out/iterate_FFNN_0/iter-1/full_period_mode2_t0.95_iter1` didn't end with .html. Adding .html to the end of your file.
# ========================= Model 1 =========================
# model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_input (InputLayer)     (None, 156)               0
# _________________________________________________________________
# dense_hidden_0 (Dense)       (None, 171)               26847
# _________________________________________________________________
# dropout_hidden_0 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_hidden_1 (Dense)       (None, 171)               29412
# _________________________________________________________________
# dropout_hidden_1 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_output (Dense)         (None, 1)                 172
# =================================================================
# Total params: 56,431
# Trainable params: 56,431
# Non-trainable params: 0
# _________________________________________________________________
#
#
# --- START TRAINING ---
#
# Train on 35108 samples, validate on 8759 samples
# Epoch 1/5
# 35108/35108 [==============================] - 1s 15us/step - loss: 3055237475.2849 - mean_absolute_percentage_error: 99.9893 - mean_absolute_error: 54024.6261 - val_loss: 3325355513.8623 - val_mean_absolute_percentage_error: 99.9699 - val_mean_absolute_error: 56170.1230
# Epoch 2/5
# 35108/35108 [==============================] - 0s 12us/step - loss: 3052363317.8425 - mean_absolute_percentage_error: 99.9418 - mean_absolute_error: 53999.1262 - val_loss: 3319587898.1911 - val_mean_absolute_percentage_error: 99.8852 - val_mean_absolute_error: 56121.9985
# Epoch 3/5
# 35108/35108 [==============================] - 0s 11us/step - loss: 3044928851.1264 - mean_absolute_percentage_error: 99.8183 - mean_absolute_error: 53932.9129 - val_loss: 3306283720.3516 - val_mean_absolute_percentage_error: 99.6880 - val_mean_absolute_error: 56010.4011
# Epoch 4/5
# 35108/35108 [==============================] - 0s 11us/step - loss: 3029372098.0782 - mean_absolute_percentage_error: 99.5576 - mean_absolute_error: 53793.5813 - val_loss: 3280757422.1934 - val_mean_absolute_percentage_error: 99.3069 - val_mean_absolute_error: 55795.1563
# Epoch 5/5
# 35108/35108 [==============================] - 0s 11us/step - loss: 3001220153.1676 - mean_absolute_percentage_error: 99.0835 - mean_absolute_error: 53540.2054 - val_loss: 3237051865.9463 - val_mean_absolute_percentage_error: 98.6492 - val_mean_absolute_error: 55423.8839
#                                       name  layer_dims dropout_rates  \
# 0  period_1_FFNN_l171*2_d0.1*2_cmcaae_norm  [171, 171]    [0.1, 0.1]
#
#   batchsize best_iter     train_mse    train_mae  train_mape      test_mse  \
# 0      3000         5  2.979111e+09  53339.91584   98.708118  3.237052e+09
#
#        test_mae  test_mape
# 0  55423.877688  98.649168
# ========================= Model 2 =========================
# model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_input (InputLayer)     (None, 156)               0
# _________________________________________________________________
# dense_hidden_0 (Dense)       (None, 171)               26847
# _________________________________________________________________
# dropout_hidden_0 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_hidden_1 (Dense)       (None, 171)               29412
# _________________________________________________________________
# dropout_hidden_1 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_output (Dense)         (None, 1)                 172
# =================================================================
# Total params: 56,431
# Trainable params: 56,431
# Non-trainable params: 0
# _________________________________________________________________
#
#
# --- START TRAINING ---
#
# Train on 35108 samples, validate on 8759 samples
# Epoch 1/5
# 35108/35108 [==============================] - 1s 25us/step - loss: 3123917971.9066 - mean_absolute_percentage_error: 99.9905 - mean_absolute_error: 54568.9143 - val_loss: 3051130880.0000 - val_mean_absolute_percentage_error: 99.9755 - val_mean_absolute_error: 53995.8361
# Epoch 2/5
# 35108/35108 [==============================] - 1s 15us/step - loss: 3121491234.4464 - mean_absolute_percentage_error: 99.9491 - mean_absolute_error: 54547.0579 - val_loss: 3047104468.3932 - val_mean_absolute_percentage_error: 99.9052 - val_mean_absolute_error: 53959.0644
# Epoch 3/5
# 35108/35108 [==============================] - 0s 11us/step - loss: 3114938089.4830 - mean_absolute_percentage_error: 99.8376 - mean_absolute_error: 54488.0610 - val_loss: 3037439085.1924 - val_mean_absolute_percentage_error: 99.7366 - val_mean_absolute_error: 53870.7973
# Epoch 4/5
# 35108/35108 [==============================] - 0s 9us/step - loss: 3100782280.5824 - mean_absolute_percentage_error: 99.5968 - mean_absolute_error: 54360.5084 - val_loss: 3018378575.5269 - val_mean_absolute_percentage_error: 99.4031 - val_mean_absolute_error: 53696.1185
# Epoch 5/5
# 35108/35108 [==============================] - 0s 9us/step - loss: 3074783916.1736 - mean_absolute_percentage_error: 99.1524 - mean_absolute_error: 54125.0810 - val_loss: 2985452454.2144 - val_mean_absolute_percentage_error: 98.8232 - val_mean_absolute_error: 53392.4344
#                                       name  layer_dims dropout_rates  \
# 0  period_3_FFNN_l171*2_d0.1*2_cmcaae_norm  [171, 171]    [0.1, 0.1]
#
#   batchsize best_iter     train_mse     train_mae  train_mape      test_mse  \
# 0      3000         5  3.054216e+09  53938.019498   98.799398  2.985452e+09
#
#        test_mae  test_mape
# 0  53392.425134  98.823224
# ========================= Model 3 =========================
# model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_input (InputLayer)     (None, 156)               0
# _________________________________________________________________
# dense_hidden_0 (Dense)       (None, 171)               26847
# _________________________________________________________________
# dropout_hidden_0 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_hidden_1 (Dense)       (None, 171)               29412
# _________________________________________________________________
# dropout_hidden_1 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_output (Dense)         (None, 1)                 172
# =================================================================
# Total params: 56,431
# Trainable params: 56,431
# Non-trainable params: 0
# _________________________________________________________________
#
#
# --- START TRAINING ---
#
# Train on 35132 samples, validate on 8735 samples
# Epoch 1/5
# 35132/35132 [==============================] - 0s 13us/step - loss: 3100634377.6186 - mean_absolute_percentage_error: 99.9906 - mean_absolute_error: 54406.3799 - val_loss: 3144201206.1820 - val_mean_absolute_percentage_error: 99.9726 - val_mean_absolute_error: 54645.6621
# Epoch 2/5
# 35132/35132 [==============================] - 0s 11us/step - loss: 3098050254.6829 - mean_absolute_percentage_error: 99.9469 - mean_absolute_error: 54383.2080 - val_loss: 3139415263.1757 - val_mean_absolute_percentage_error: 99.8930 - val_mean_absolute_error: 54603.1696
# Epoch 3/5
# 35132/35132 [==============================] - 0s 10us/step - loss: 3091262329.3690 - mean_absolute_percentage_error: 99.8316 - mean_absolute_error: 54322.1118 - val_loss: 3128179199.1208 - val_mean_absolute_percentage_error: 99.7049 - val_mean_absolute_error: 54503.0206
# Epoch 4/5
# 35132/35132 [==============================] - 0s 10us/step - loss: 3076840275.4193 - mean_absolute_percentage_error: 99.5853 - mean_absolute_error: 54191.7570 - val_loss: 3106226057.0120 - val_mean_absolute_percentage_error: 99.3352 - val_mean_absolute_error: 54306.3603
# Epoch 5/5
# 35132/35132 [==============================] - 0s 9us/step - loss: 3050397756.9177 - mean_absolute_percentage_error: 99.1314 - mean_absolute_error: 53951.5650 - val_loss: 3068434990.0126 - val_mean_absolute_percentage_error: 98.6937 - val_mean_absolute_error: 53965.2754
#                                       name  layer_dims dropout_rates  \
# 0  period_5_FFNN_l171*2_d0.1*2_cmcaae_norm  [171, 171]    [0.1, 0.1]
#
#   batchsize best_iter     train_mse     train_mae  train_mape      test_mse  \
# 0      3000         5  3.029688e+09  53762.332471   98.773383  3.068435e+09
#
#        test_mae  test_mape
# 0  53965.285687  98.693755
# ========================= Model 4 =========================
# model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_input (InputLayer)     (None, 156)               0
# _________________________________________________________________
# dense_hidden_0 (Dense)       (None, 171)               26847
# _________________________________________________________________
# dropout_hidden_0 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_hidden_1 (Dense)       (None, 171)               29412
# _________________________________________________________________
# dropout_hidden_1 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_output (Dense)         (None, 1)                 172
# =================================================================
# Total params: 56,431
# Trainable params: 56,431
# Non-trainable params: 0
# _________________________________________________________________
#
#
# --- START TRAINING ---
#
# Train on 35108 samples, validate on 8759 samples
# Epoch 1/5
# 35108/35108 [==============================] - 0s 14us/step - loss: 3160819361.5568 - mean_absolute_percentage_error: 99.9900 - mean_absolute_error: 54875.1877 - val_loss: 2903060687.8630 - val_mean_absolute_percentage_error: 99.9759 - val_mean_absolute_error: 52767.1391
# Epoch 2/5
# 35108/35108 [==============================] - 0s 12us/step - loss: 3158172229.3303 - mean_absolute_percentage_error: 99.9460 - mean_absolute_error: 54851.6677 - val_loss: 2899253301.6609 - val_mean_absolute_percentage_error: 99.9054 - val_mean_absolute_error: 52731.1800
# Epoch 3/5
# 35108/35108 [==============================] - 0s 10us/step - loss: 3151059908.7615 - mean_absolute_percentage_error: 99.8259 - mean_absolute_error: 54787.9095 - val_loss: 2889927657.0275 - val_mean_absolute_percentage_error: 99.7306 - val_mean_absolute_error: 52642.6140
# Epoch 4/5
# 35108/35108 [==============================] - 0s 10us/step - loss: 3135576543.3328 - mean_absolute_percentage_error: 99.5613 - mean_absolute_error: 54648.0356 - val_loss: 2871455286.1286 - val_mean_absolute_percentage_error: 99.3820 - val_mean_absolute_error: 52466.1820
# Epoch 5/5
# 35108/35108 [==============================] - 0s 9us/step - loss: 3107230706.9331 - mean_absolute_percentage_error: 99.0725 - mean_absolute_error: 54390.1638 - val_loss: 2839693483.9137 - val_mean_absolute_percentage_error: 98.7775 - val_mean_absolute_error: 52160.5205
#                                       name  layer_dims dropout_rates  \
# 0  period_2_FFNN_l171*2_d0.1*2_cmcaae_norm  [171, 171]    [0.1, 0.1]
#
#   batchsize best_iter     train_mse    train_mae  train_mape      test_mse  \
# 0      3000         5  3.084846e+09  54185.65929   98.685257  2.839694e+09
#
#        test_mae  test_mape
# 0  52160.528553  98.777489
# ========================= Model 5 =========================
# model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_input (InputLayer)     (None, 156)               0
# _________________________________________________________________
# dense_hidden_0 (Dense)       (None, 171)               26847
# _________________________________________________________________
# dropout_hidden_0 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_hidden_1 (Dense)       (None, 171)               29412
# _________________________________________________________________
# dropout_hidden_1 (Dropout)   (None, 171)               0
# _________________________________________________________________
# dense_output (Dense)         (None, 1)                 172
# =================================================================
# Total params: 56,431
# Trainable params: 56,431
# Non-trainable params: 0
# _________________________________________________________________
#
#
# --- START TRAINING ---
#
# Train on 35084 samples, validate on 8783 samples
# Epoch 1/5
# 35084/35084 [==============================] - 0s 13us/step - loss: 3107268657.2678 - mean_absolute_percentage_error: 99.9927 - mean_absolute_error: 54408.8647 - val_loss: 3118569973.9442 - val_mean_absolute_percentage_error: 99.9796 - val_mean_absolute_error: 54643.4748
# Epoch 2/5
# 35084/35084 [==============================] - 0s 10us/step - loss: 3105203165.2965 - mean_absolute_percentage_error: 99.9578 - mean_absolute_error: 54390.3731 - val_loss: 3114978009.8463 - val_mean_absolute_percentage_error: 99.9185 - val_mean_absolute_error: 54611.0852
# Epoch 3/5
# 35084/35084 [==============================] - 0s 10us/step - loss: 3099432974.3601 - mean_absolute_percentage_error: 99.8625 - mean_absolute_error: 54339.2209 - val_loss: 3105946882.0403 - val_mean_absolute_percentage_error: 99.7671 - val_mean_absolute_error: 54530.1337
# Epoch 4/5
# 35084/35084 [==============================] - 0s 9us/step - loss: 3086522440.5591 - mean_absolute_percentage_error: 99.6509 - mean_absolute_error: 54225.1243 - val_loss: 3087641874.3336 - val_mean_absolute_percentage_error: 99.4610 - val_mean_absolute_error: 54366.0818
# Epoch 5/5
# 35084/35084 [==============================] - 0s 9us/step - loss: 3062402914.2729 - mean_absolute_percentage_error: 99.2546 - mean_absolute_error: 54011.2843 - val_loss: 3055524281.8427 - val_mean_absolute_percentage_error: 98.9227 - val_mean_absolute_error: 54077.1206
#                                       name  layer_dims dropout_rates  \
# 0  period_4_FFNN_l171*2_d0.1*2_cmcaae_norm  [171, 171]    [0.1, 0.1]
#
#   batchsize best_iter     train_mse     train_mae  train_mape      test_mse  \
# 0      3000         5  3.043090e+09  53839.991099   98.938259  3.055524e+09
#
#        test_mae  test_mape
# 0  54077.120085  98.922719
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]
# [ (2,1) x1,y2 ]
# [ (3,1) x1,y3 ]
# [ (4,1) x1,y4 ]
# /local/home/antorosi/PycharmProjects/KERAS-TS-VENV/lib/python3.5/site-packages/plotly/offline/offline.py:459: UserWarning:
#
# Your filename `/home/antorosi/Documents/Prediction/out/iterate_FFNN_0/iter-2/full_period_mode2_t0.95_iter2` didn't end with .html. Adding .html to the end of your file.
